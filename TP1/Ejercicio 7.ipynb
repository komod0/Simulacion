# %%
from mpl_toolkits.mplot3d import Axes3D
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
plt.rcParams["figure.figsize"] = (10,10)

# %% [markdown]
# ## Defino el generador del ejercicio 1

# %%
SEED = np.floor((100680+101046+101018+100490) / 4)
def gen_lin_norm (n,seed,a,c,m):
    x = seed
    vector = []
    for i in range(n):
        x = ((a*x+c)%m)
        vector.append(x/m)
    return vector

# %% [markdown]
# ## Test espectral en 2 dimensiones (tomo de a pares los numeros generados y analizo si hay o no patrones visibles)

# %%
nums = gen_lin_norm(1000000,SEED,1013904223,1664525,2**32)

# %% [markdown]
# ### 1000 numeros

# %%
x = []
y = []
z = []
for i in range(998):
    x.append(nums[i])
    y.append(nums[i+1])
    z.append(nums[i+2])

# %%
sns.scatterplot(x,y)
plt.xlim(left=0, right=1)
plt.ylim(bottom=0, top=1)
plt.grid()
plt.title('Generador lineal 1.000 de puntos\n', fontsize = 15);

# %% [markdown]
# ### 10.000 numeros

# %%
x = []
y = []
z = []
for i in range(9998):
    x.append(nums[i])
    y.append(nums[i+1])
    z.append(nums[i+2])

# %%
sns.scatterplot(x,y, s=20)
plt.xlim(left=0, right=1)
plt.ylim(bottom=0, top=1)
plt.grid()
plt.title('Generador lineal 10.000 de puntos\n', fontsize = 15);

# %% [markdown]
# ### 100.000 numeros

# %%
x = []
y = []
z = []
for i in range(99998):
    x.append(nums[i])
    y.append(nums[i+1])
    z.append(nums[i+2])

# %%
sns.scatterplot(x,y,s=20)
plt.xlim(left=0, right=1)
plt.ylim(bottom=0, top=1)
plt.grid()
plt.title('Generador lineal 100.000 de puntos\n', fontsize = 15);

# %% [markdown]
# ### 1.000.000 numeros

# %%
x = []
y = []
z = []
for i in range(999998):
    x.append(nums[i])
    y.append(nums[i+1])
    z.append(nums[i+2])

# %%
sns.scatterplot(x,y, s=20)
plt.xlim(left=0, right=1)
plt.ylim(bottom=0, top=1)
plt.grid()
plt.title('Generador lineal 1.000.000 de puntos\n', fontsize = 15);

# %% [markdown]
# ## Parece ser lo suficientemente random, por lo que pasa el test espectral en 2 dimensiones

# %% [markdown]
# # Test espectral en 3 dimensiones

# %% [markdown]
# ### 100.000 numeros

# %%
x = []
y = []
z = []
for i in range(99998):
    x.append(nums[i])
    y.append(nums[i+1])
    z.append(nums[i+2])

# %%
fig = plt.figure()
ax = fig.gca(projection='3d')
ax.scatter(x, y, z, c='firebrick', s=20)
ax.set_xlim(left=0, right=1)
ax.set_ylim(bottom=0, top=1)
ax.set_zlim(bottom=0, top=1)
plt.grid()
ax.set_xlabel('Eje X')
ax.set_ylabel('Eje Y')
ax.set_zlabel('Eje Z')
ax.view_init(0, 0)
plt.title('Generador lineal 100.000 de puntos\n', fontsize = 15);

# %%
fig = plt.figure()
ax = fig.gca(projection='3d')
ax.scatter(x, y, z, c='firebrick', s=20)
ax.set_xlim(left=0, right=1)
ax.set_ylim(bottom=0, top=1)
ax.set_zlim(bottom=0, top=1)
plt.grid()
ax.set_xlabel('Eje X')
ax.set_ylabel('Eje Y')
ax.set_zlabel('Eje Z')
ax.view_init(0, 15)
plt.title('Generador lineal 100.000 de puntos (rotacion 15°)\n', fontsize = 15);

# %%
fig = plt.figure()
ax = fig.gca(projection='3d')
ax.scatter(x, y, z, c='firebrick', s=20)
ax.set_xlim(left=0, right=1)
ax.set_ylim(bottom=0, top=1)
ax.set_zlim(bottom=0, top=1)
plt.grid()
ax.set_xlabel('Eje X')
ax.set_ylabel('Eje Y')
ax.set_zlabel('Eje Z')
ax.view_init(0, 30)
plt.title('Generador lineal 100.000 de puntos (rotacion 30°)\n', fontsize = 15);

# %%
fig = plt.figure()
ax = fig.gca(projection='3d')
ax.scatter(x, y, z, c='firebrick', s=20)
ax.set_xlim(left=0, right=1)
ax.set_ylim(bottom=0, top=1)
ax.set_zlim(bottom=0, top=1)
plt.grid()
ax.set_xlabel('Eje X')
ax.set_ylabel('Eje Y')
ax.set_zlabel('Eje Z')
ax.view_init(0, 45)
plt.title('Generador lineal 100.000 de puntos (rotacion 45°)\n', fontsize = 15);

# %%
fig = plt.figure()
ax = fig.gca(projection='3d')
ax.scatter(x, y, z, c='firebrick', s=20)
ax.set_xlim(left=0, right=1)
ax.set_ylim(bottom=0, top=1)
ax.set_zlim(bottom=0, top=1)
plt.grid()
ax.set_xlabel('Eje X')
ax.set_ylabel('Eje Y')
ax.set_zlabel('Eje Z')
ax.view_init(90, 0)
plt.title('Generador lineal 100.000 de puntos (elevacion de 90° en eje z)\n', fontsize = 15);

# %%
fig = plt.figure()
ax = fig.gca(projection='3d')
ax.scatter(x, y, z, c='firebrick', s=20)
ax.set_xlim(left=0.9, right=1)
ax.set_ylim(bottom=0, top=0.1)
ax.set_zlim(bottom=0, top=0.1)
plt.grid()
ax.set_xlabel('Eje X')
ax.set_ylabel('Eje Y')
ax.set_zlabel('Eje Z')
ax.view_init(0, 0)
plt.title('Generador lineal 100.000 de puntos (zoom x10)\n', fontsize = 15);

# %% [markdown]
# ### Ubico al eje X entre 0.9 y 1 para que la "camara" del punto de vista" este fuera del cubo en el que se generan los puntos, se puede ubicar al eje Z entre 0.9 y 1 para que los puntos no tapen el titulo pero de todas formas se superponen con los ejes asi que hay que decidir que grafico queda menos desprolijo

# %% [markdown]
# ## Parece ser lo suficientemente random (uniforme) puesto que genera un cubo denso al generar 100.000 numeros. Pasa el test espectral en 3 dimensiones
