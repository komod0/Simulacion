# %%
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import sys
sb.set()

# %% [markdown]
# ## Punto A y B

# %%
SEED = np.floor((100680+101046+101018+100490) / 4)

# %%
def dens_normal(sigma, mu, x):
    a = 1/(sigma*np.sqrt(2*np.pi))
    b = np.exp(-((x-mu)**2)/(2*sigma**2))
    return a*b

def dens_exp(lbda, x):
    return lbda * 1*np.exp(-lbda * abs(x))

# %%
#Para aceptar o rechazar
c = 75/5

def aceptar(x):
    u = np.random.rand()
    a = dens_normal(np.sqrt(3), 15, x)/ (c * (dens_exp(1/15, x)))
    return u < a

# %%
cant_gen = 0
rechazados = 0
gen = []
while (cant_gen < 100000):
    x = np.random.exponential(scale = 15, size = 1)[0] #scale = 1/lambda
    u = np.random.rand()
    if (u < 0.5):
        x = -x
    if (aceptar(x)):
        cant_gen+=1
        gen.append(x)
    else: 
        rechazados+=1

# %%
plt.figure(figsize=[15,10])
sb.distplot(gen, kde = True);

# %% [markdown]
# ## Punto C

# %%
#Generados 100000 numeros normales con la funcion de Numpy Python
gen_py = np.random.normal(loc = 15, scale = np.sqrt(3))

# %%
plt.figure(figsize=[15,10])
sb.distplot(gen, kde = True);

# %% [markdown]
# ## Punto D

# %%
np.mean(gen)
# Out:
# 15.004129001656242

# %%
np.var(gen)
# Out:
# 3.011836259984689

# %% [markdown]
# ## Punto E

# %%
#La eficiencia la calculamos total de numeros generados, sobre el total de aceptados
total = rechazados + cant_gen

# %%
eficiencia = cant_gen/ total
print(eficiencia)
# Out:
# 0.03332029399161795
